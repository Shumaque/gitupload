# %% [markdown]
# <a href="https://colab.research.google.com/github/Shumaque/gitupload/blob/main/dataframing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sumarizing data stastically
import seaborn as sns
import pandas as pd
data={
    "Roll No":[6232,6233,6231,6234,6235,6236,6232],
    "Name":['Shumaque','Piyush','Naufil','Purva','Anushka','Gargi','Shumaque'],
    "Marks":[80,70,50,40,60,99,80]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Roll No      Name  Marks
# 0     6232  Shumaque     80
# 1     6233    Piyush     70
# 2     6231    Naufil     50
# 3     6234     Purva     40
# 4     6235   Anushka     60
# 5     6236     Gargi     99
# 6     6232  Shumaque     80

# %%
df.isnull().sum()
# Out:
# Roll No    0
# Name       0
# Marks      0
# dtype: int64

# %%
df.isnull()
# Out:
#    Roll No   Name  Marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# 5    False  False  False

# %%
df.describe()
# Out:
#            Roll No      Marks
# count     6.000000   6.000000
# mean   6233.833333  66.500000
# std       1.471960  21.295539
# min    6232.000000  40.000000
# 25%    6233.000000  52.500000
# 50%    6233.500000  65.000000
# 75%    6234.750000  77.500000
# max    6236.000000  99.000000

# %%
df.describe(include='object')
# Out:
#             Name
# count          6
# unique         6
# top     Shumaque
# freq           1

# %%
df.shape
# Out:
# (6, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll No  6 non-null      int64
#  1   Name     6 non-null      object
#  2   Marks    6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# Roll No    5
# Name       6
# Marks      6
# dtype: int64

# %%
df.value_counts()
# Out:
# Roll No  Name      Marks
# 6232     Shumaque  80       2
# 6231     Naufil    50       1
# 6233     Piyush    70       1
# 6234     Purva     40       1
# 6235     Anushka   60       1
# 6236     Gargi     99       1
# dtype: int64

# %%
df['Name']
# Out:
# 0    Shumaque
# 1      Piyush
# 2      Naufil
# 3       Purva
# 4     Anushka
# 5       Gargi
# 6    Shumaque
# Name: Name, dtype: object

# %%
x=df.corr()
# Out:
# <ipython-input-33-2a9eb634181f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x=df.corr()

# %%
sns.heatmap(x,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.mean()
df.var()
# Out:
# <ipython-input-42-9a5d178dda8a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# <ipython-input-42-9a5d178dda8a>:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll No      3.238095
# Marks      403.952381
# dtype: float64

# %%
df['Marks'].var()
# Out:
# 403.9523809523809

# %%
df.cov()
# Out:
# <ipython-input-45-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#            Roll No       Marks
# Roll No   3.238095   10.023810
# Marks    10.023810  403.952381
